# %% [markdown]
# # 2. Pengumpulan Data

# %% [markdown]
# # Scrapping Data 3000 butir

# %%
# %pip install google_play_scraper
# %pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrapping 3000 Data

# %%
# Scrap some reviews aplikasi reku di playstore
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.jobstreet.jobstreet',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    count=3000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 for only 1 star, 2 for 2 star, 3 for 3 star, 4 for 4 star and 5 for 5 star.
)

df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.to_csv('Dataset/ulasanapp_3000_selected.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('Dataset/ulasanapp_3000_selected.csv')
df
# Out:
#                                   reviewId         userName  \
# 0     27723ced-9f2d-41ac-8611-5a9913e89713  Pengguna Google
# 1     48a85e3d-0759-4635-b640-228f0a84b7b3  Pengguna Google
# 2     8960f04f-96f0-4da7-bec7-5a6c01e472f0  Pengguna Google
# 3     d1b15dbc-48ee-4e2f-8297-6ea7093a53b7  Pengguna Google
# 4     aa54f93d-92c1-4ec6-8488-2c27e4d9c566  Pengguna Google
# ...                                    ...              ...
# 2995  f1999778-aa39-4ae5-9217-8dddb0eb173b  Pengguna Google
# 2996  d8dcf9a8-8a67-42e6-b9b2-ebdd4a521ff3  Pengguna Google
# 2997  b88b7d06-d330-4535-9283-56c6a10ceda2  Pengguna Google
# 2998  d2294cb8-2ce0-4437-a193-0100be2e00a1  Pengguna Google
# 2999  bcacf798-7a4b-40d6-9699-c0d6c4e79b9a  Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
pd.set_option('display.max_colwidth', None)
df[['content']].head(6)
# Out:
#                                                                                                                                                                                                                                                                                                                                     content
# 0                                                                                                                                                                                                                                                                                  potongan nya skr sangat tidak masuk akal,sudh hampir 10%
# ...

# %% [markdown]
# # Scrapping All Data

# %%
# Scrap all reviews aplikasi reku di playstore
from google_play_scraper import Sort, reviews_all

review = reviews_all(
    'com.jobstreet.jobstreet',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST # defaults to Sort.MOST_RELEVANT
)

df_ulasanapp = pd.DataFrame(np.array(review), columns=['content'])
df_ulasanapp = df_ulasanapp.join(pd.DataFrame(df_ulasanapp.pop('content').tolist()))
df_ulasanapp.to_csv('Dataset/ulasanapp_all_selected.csv', index=False)

# %%
df_ulasanapp2 = pd.read_csv('Dataset/ulasanapp_all_selected.csv')
df_ulasanapp2
# Out:
#                                     reviewId         userName  \
# 0       642f2a07-8c38-4b2f-b3cc-dd19f1d07e4a  Pengguna Google
# 1       bef09f1a-dbb3-4d1e-a782-409f583b25b7  Pengguna Google
# 2       04e2fe8e-9ef7-42b7-af90-2e561d1bfca1  Pengguna Google
# 3       bffc8404-ede7-4a63-ab60-776344a903af  Pengguna Google
# 4       a2f01be4-030f-470f-8ddb-b1c804ec30b9  Pengguna Google
# ...                                      ...              ...
# 113437  8d108573-c65a-4cf0-9477-8a965bcefe36  Pengguna Google
# 113438  042a4624-d96a-4da6-80e4-316925c8fe64  Pengguna Google
# 113439  90c1bfd6-b2bb-4148-a253-c9b5c40d334f  Pengguna Google
# 113440  116fd638-85e0-448c-9d83-846fab9ba826  Pengguna Google
# 113441  986cf763-b4fa-4319-9b67-b52963d456a3  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# ...
