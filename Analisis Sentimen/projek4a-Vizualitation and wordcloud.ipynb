# %%
import pandas as pd

df = pd.read_csv('Dataset/ulasanapp_3000_hasillabeling.csv')
df.head()
# Out:
#    score                                            content  \
# 0      5  Terletak di depan Lapangan Jetayu, menempati b...
# 1      5  Baru pertama kemuseum ini, dan dari beberapa m...
# 2      5  Koleksi batik lengkap dan bisa hands-on nyoba ...
# 3      5  Akhirnya kesampean buat mampir ke museum ini. ...
# 4      5  Suka sekali, tiket nya Murmer cm 7000 per org....
#
#                                           text_clean  \
# 0  terletak di depan lapangan jetayu menempati ba...
# 1  baru pertama kemuseum ini dan dari beberapa mu...
# 2  koleksi batik lengkap dan bisa handson nyoba m...
# 3  akhirnya kesampean buat mampir ke museum ini h...
# 4  suka sekali tiket nya murmer cm 7000 per org b...
#
#                                        text_Stopword  \
# 0  terletak lapangan jetayu menempati bangunan tu...
# 1  kemuseum museum batik yg kunjungi koleksi muse...
# 2  koleksi batik lengkap handson nyoba membatik m...
# 3  kesampean mampir museum htm 7 ribu rupiah peng...
# 4  suka tiket nya murmer cm 7000 org bs batik trs...
#
#                                          text_tokens  \
# 0  ['terletak', 'lapangan', 'jetayu', 'menempati'...
# 1  ['kemuseum', 'museum', 'batik', 'yg', 'kunjung...
# 2  ['koleksi', 'batik', 'lengkap', 'handson', 'ny...
# 3  ['kesampean', 'mampir', 'museum', 'htm', '7', ...
# 4  ['suka', 'tiket', 'nya', 'murmer', 'cm', '7000...
#
#                                  text_tokens_stemmed    Label
# 0  letak lapang jetayu tempat bangun tua khas tin...  positif
# 1  museum museum batik yg kunjung koleksi museum ...  positif
# 2  koleksi batik lengkap handson nyoba batik muda...  positif
# 3  sampean mampir museum htm 7 ribu rupiah unjung...  positif
# 4  suka tiket nya murmer cm 7000 org bs batik trs...  positif

# %%
my_df = df.sort_values(by=['at'], ascending=False)
my_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10084\2636746527.py in ?()
# ----> 1 my_df = df.sort_values(by=['at'], ascending=False)
#       2 my_df.head()
#
# c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'at'

# %%
my_df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      1  2024-12-12 08:14:23
# 1  Pengguna Google      2  2024-12-12 04:27:59
# 2  Pengguna Google      1  2024-12-11 23:41:41
# 3  Pengguna Google      1  2024-12-11 22:51:25
# 4  Pengguna Google      5  2024-12-11 12:00:10
#
#                                              content  \
# 0  Setiap apply lamaran disini, bbrpa hari atau b...
# 1                                           Worth it
# 2           Jadi susah re login by seek, gagal terus
# 3  TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...
# 4                                          Excellent
#
#                                           text_clean  \
# 0  setiap apply lamaran disini bbrpa hari atau bb...
# 1                                           worth it
# 2            jadi susah re login by seek gagal terus
# 3  tolong di perbaiki masalah yang ada di aplikas...
# 4                                          excellent
#
#                                        text_Stopword  \
# 0  apply lamaran bbrpa bbrpa minggu balasan stiap...
# 1                                           worth it
# 2                       susah re login by seek gagal
# 3  tolong perbaiki aplikasi login eror gausah sur...
# 4                                          excellent
#
#                                          text_tokens  \
# 0  ['apply', 'lamaran', 'bbrpa', 'bbrpa', 'minggu...
# 1                                    ['worth', 'it']
# 2    ['susah', 're', 'login', 'by', 'seek', 'gagal']
# 3  ['tolong', 'perbaiki', 'aplikasi', 'login', 'e...
# 4                                      ['excellent']
#
#                                  text_tokens_stemmed    Label
# 0  apply lamar bbrpa bbrpa minggu balas stiap per...  negatif
# 1                                           worth it  negatif
# 2                       susah re login by seek gagal  negatif
# 3  tolong baik aplikasi login eror gausah suruh s...  negatif
# 4                                          excellent  positif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2753 entries, 0 to 2752
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   userName             2753 non-null   object
#  1   score                2753 non-null   int64
#  2   at                   2753 non-null   object
#  3   content              2753 non-null   object
#  4   text_clean           2742 non-null   object
#  5   text_Stopword        2723 non-null   object
#  6   text_tokens          2753 non-null   object
#  7   text_tokens_stemmed  2723 non-null   object
#  8   Label                2753 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 193.7+ KB

# %%
my_df.isna()
# Out:
#       userName  score     at  content  text_clean  text_Stopword  text_tokens  \
# 0        False  False  False    False       False          False        False
# 1        False  False  False    False       False          False        False
# 2        False  False  False    False       False          False        False
# 3        False  False  False    False       False          False        False
# 4        False  False  False    False       False          False        False
# ...        ...    ...    ...      ...         ...            ...          ...
# 2748     False  False  False    False       False          False        False
# 2749     False  False  False    False       False          False        False
# 2750     False  False  False    False       False          False        False
# 2751     False  False  False    False       False          False        False
# 2752     False  False  False    False       False          False        False
#
#       text_tokens_stemmed  Label
# 0                   False  False
# 1                   False  False
# 2                   False  False
# 3                   False  False
# 4                   False  False
# ...                   ...    ...
# 2748                False  False
# 2749                False  False
# 2750                False  False
# 2751                False  False
# 2752                False  False
#
# [2753 rows x 9 columns]

# %%
my_df.isna().any()
# Out:
# userName               False
# score                  False
# at                     False
# content                False
# text_clean              True
# text_Stopword           True
# text_tokens            False
# text_tokens_stemmed     True
# Label                  False
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2753.000000
# mean      3.184889
# std       1.859616
# min       1.000000
# 25%       1.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# userName                0
# score                   0
# at                      0
# content                 0
# text_clean             11
# text_Stopword          30
# text_tokens             0
# text_tokens_stemmed    30
# Label                   0
# dtype: int64

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Semua

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
# netral_tweets = my_df[my_df['Label'] == 'None']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
# netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(all_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Positif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
netral_tweets = my_df[my_df['Label'] == 'positif']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# # Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
# all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(netral_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Negatif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
netral_tweets = my_df[my_df['Label'] == 'negatif']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# # Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
# all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(netral_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)
