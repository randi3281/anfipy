# %% [markdown]
# # 2. Pengumpulan Data

# %% [markdown]
# # Scrapping Data 3000 butir

# %%
# %pip install google_play_scraper
# %pip install wordcloud
# Out:
# Requirement already satisfied: google_play_scraper in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (1.2.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: wordcloud in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from wordcloud) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anfiniti\codes\anfipy\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from google_play_scraper import app
# ----> 2 import pandas as pd
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\api.py:47
#      45 from pandas.core.construction import array
#      46 from pandas.core.flags import Flags
# ---> 47 from pandas.core.groupby import (
#      48     Grouper,
#      49     NamedAgg,
#      50 )
#      51 from pandas.core.indexes.api import (
#      52     CategoricalIndex,
#      53     DatetimeIndex,
#    (...)
#      59     TimedeltaIndex,
#      60 )
#      61 from pandas.core.indexes.datetimes import (
#      62     bdate_range,
#      63     date_range,
#      64 )
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\groupby\__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\groupby\generic.py:68
#      60 from pandas.core.apply import (
#      61     GroupByApply,
#      62     maybe_mangle_lambdas,
#    (...)
#      65     warn_alias_replacement,
#      66 )
#      67 import pandas.core.common as com
# ---> 68 from pandas.core.frame import DataFrame
#      69 from pandas.core.groupby import (
#      70     base,
#      71     ops,
#      72 )
#      73 from pandas.core.groupby.groupby import (
#      74     GroupBy,
#      75     GroupByPlot,
#    (...)
#      79     _transform_template,
#      80 )
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\frame.py:149
#     143 from pandas.core.arrays.sparse import SparseFrameAccessor
#     144 from pandas.core.construction import (
#     145     ensure_wrapped_if_datetimelike,
#     146     sanitize_array,
#     147     sanitize_masked_array,
#     148 )
# --> 149 from pandas.core.generic import (
#     150     NDFrame,
#     151     make_doc,
#     152 )
#     153 from pandas.core.indexers import check_key_length
#     154 from pandas.core.indexes.api import (
#     155     DatetimeIndex,
#     156     Index,
#    (...)
#     160     ensure_index_from_sequences,
#     161 )
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\generic.py:152
#     143 from pandas.core.dtypes.inference import (
#     144     is_hashable,
#     145     is_nested_list_like,
#     146 )
#     147 from pandas.core.dtypes.missing import (
#     148     isna,
#     149     notna,
#     150 )
# --> 152 from pandas.core import (
#     153     algorithms as algos,
#     154     arraylike,
#     155     common,
#     156     indexing,
#     157     missing,
#     158     nanops,
#     159     sample,
#     160 )
#     161 from pandas.core.array_algos.replace import should_use_regex
#     162 from pandas.core.arrays import ExtensionArray
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\indexing.py:79
#      69 from pandas.core.construction import (
#      70     array as pd_array,
#      71     extract_array,
#      72 )
#      73 from pandas.core.indexers import (
#      74     check_array_indexer,
#      75     is_list_like_indexer,
#      76     is_scalar_indexer,
#      77     length_of_indexer,
#      78 )
# ---> 79 from pandas.core.indexes.api import (
#      80     Index,
#      81     MultiIndex,
#      82 )
#      84 if TYPE_CHECKING:
#      85     from collections.abc import (
#      86         Hashable,
#      87         Sequence,
#      88     )
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\indexes\api.py:20
#      17 from pandas.core.dtypes.cast import find_common_type
#      19 from pandas.core.algorithms import safe_sort
# ---> 20 from pandas.core.indexes.base import (
#      21     Index,
#      22     _new_Index,
#      23     ensure_index,
#      24     ensure_index_from_sequences,
#      25     get_unanimous_names,
#      26 )
#      27 from pandas.core.indexes.category import CategoricalIndex
#      28 from pandas.core.indexes.datetimes import DatetimeIndex
#
# File c:\Users\anfiniti\Codes\anfipy\.venv\lib\site-packages\pandas\core\indexes\base.py:29
#      21 import numpy as np
#      23 from pandas._config import (
#      24     get_option,
#      25     using_copy_on_write,
#      26     using_pyarrow_string_dtype,
#      27 )
# ---> 29 from pandas._libs import (
#      30     NaT,
#      31     algos as libalgos,
#      32     index as libindex,
#      33     lib,
#      34     writers,
#      35 )
#      36 from pandas._libs.internals import BlockValuesRefs
#      37 import pandas._libs.join as libjoin
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1430, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1402, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1535, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Scrapping 3000 Data

# %%
# Scrap some reviews aplikasi reku di playstore
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.jobstreet.jobstreet',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    count=3000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 for only 1 star, 2 for 2 star, 3 for 3 star, 4 for 4 star and 5 for 5 star.
)

df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.to_csv('Dataset/jobstreet_3000_selected.csv', index=False)

# %%
df = pd.read_csv('Dataset/jobstreet_3000_selected.csv')
df
# Out:
#                                   reviewId         userName  \
# 0     290afc12-8677-4436-a8b1-0b210794bdf7  Pengguna Google
# 1     4bc5e44e-13f9-43fd-ad80-f8f204d0f186  Pengguna Google
# 2     f38fa028-5260-441a-938c-2925ea8da6ee  Pengguna Google
# 3     6ce41673-7cd1-4969-b5a6-d7daa649e0c0  Pengguna Google
# 4     9a6a4bd7-e4b4-4d4f-8cd2-df09a24f303a  Pengguna Google
# ...                                    ...              ...
# 2995  a9defb99-ce26-4ce5-9c97-359e0dbe17d0  Pengguna Google
# 2996  0a2b2a07-9853-4663-8886-586d27d0d7b3  Pengguna Google
# 2997  debcbbe7-234b-4c00-8892-3815bf09aee8  Pengguna Google
# 2998  3a70b39d-7d19-4ca3-9e8e-e11d12b7acb6  Pengguna Google
# 2999  ec4b0605-f4c0-4051-b6fe-2db9c2ce1f88  Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 2995  https://play-lh.googleusercontent.com/EGemoI2N...
# 2996  https://play-lh.googleusercontent.com/EGemoI2N...
# 2997  https://play-lh.googleusercontent.com/EGemoI2N...
# 2998  https://play-lh.googleusercontent.com/EGemoI2N...
# 2999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0                                              Worth it      2              0
# 1              Jadi susah re login by seek, gagal terus      1              0
# 2     TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...      1              0
# 3     Masa tiap 3 hari sekali log out terus Uda masu...      3              0
# 4     ga jls apk nya baru sebentar buka udh load lam...      3              0
# ...                                                 ...    ...            ...
# 2995                                             Update      4              0
# 2996                                    Sangat membantu      5              0
# 2997  Ini kenapa selesai update ga bisa login sih, p...      1              0
# 2998                                               Good      5              0
# 2999           Sangat membantu untuk para pencari kerja      5              0
#
#      reviewCreatedVersion                   at  \
# 0                 14.33.0  2024-12-12 04:27:59
# 1                 14.32.0  2024-12-11 23:41:41
# 2                 14.32.0  2024-12-11 22:51:25
# 3                 14.33.0  2024-12-11 22:19:15
# 4                     NaN  2024-12-11 18:57:03
# ...                   ...                  ...
# 2995               5.51.0  2023-11-02 08:29:22
# 2996               5.51.0  2023-11-02 08:04:37
# 2997               12.1.2  2023-11-02 07:33:15
# 2998               5.51.0  2023-11-02 06:54:32
# 2999               5.51.0  2023-11-02 06:10:07
#
#                                            replyContent            repliedAt  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2     Hi, kami meminta maaf atas ketidaknyamanan yan...  2024-12-04 08:43:34
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 2995  Hi, terima kasih bintang limanya. Kami berhada...  2024-03-22 13:00:06
# 2996  Hi, terima kasih bintang limanya. Kami berhada...  2024-03-22 13:00:46
# 2997  Hi, kami meminta maaf atas ketidaknyamanan yan...  2023-11-04 20:23:32
# 2998  Hi, terima kasih bintang limanya. Kami berhada...  2024-03-22 13:00:06
# 2999  Hi, terima kasih bintang limanya. Kami berhada...  2024-03-22 13:00:05
#
#      appVersion
# 0       14.33.0
# 1       14.32.0
# 2       14.32.0
# 3       14.33.0
# 4           NaN
# ...         ...
# 2995     5.51.0
# 2996     5.51.0
# 2997     12.1.2
# 2998     5.51.0
# 2999     5.51.0
#
# [3000 rows x 11 columns]

# %% [markdown]
# # Scrapping All Data

# %%
# Scrap all reviews aplikasi reku di playstore
from google_play_scraper import Sort, reviews_all

review = reviews_all(
    'com.jobstreet.jobstreet',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST # defaults to Sort.MOST_RELEVANT
)

df_jobstreet = pd.DataFrame(np.array(review), columns=['content'])
df_jobstreet = df_jobstreet.join(pd.DataFrame(df_jobstreet.pop('content').tolist()))
df_jobstreet.to_csv('Dataset\jobstreet_all_selected.csv', index=False)

# %%
df_jobstreet2 = pd.read_csv('Dataset\jobstreet_all_selected.csv')
df_jobstreet2
# Out:
#                                    reviewId         userName  \
# 0      8d7ef114-6f71-4636-b310-74bee64c4486  Pengguna Google
# 1      5346efe6-db13-40d4-a928-53197f078601  Pengguna Google
# 2      290afc12-8677-4436-a8b1-0b210794bdf7  Pengguna Google
# 3      4bc5e44e-13f9-43fd-ad80-f8f204d0f186  Pengguna Google
# 4      f38fa028-5260-441a-938c-2925ea8da6ee  Pengguna Google
# ...                                     ...              ...
# 73985  29573f6d-2244-41b7-ab60-25ca0c133a23  Pengguna Google
# 73986  e390a8c1-375e-412e-92da-9201985139dc  Pengguna Google
# 73987  de102882-8a10-4b2e-8685-8a2bae839540  Pengguna Google
# 73988  3e59386e-e8f2-4dd4-b8a3-101be8485157  Pengguna Google
# 73989  132e2473-fc46-453b-aaf4-1fd51a83dc36  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 73985  https://play-lh.googleusercontent.com/EGemoI2N...
# 73986  https://play-lh.googleusercontent.com/EGemoI2N...
# 73987  https://play-lh.googleusercontent.com/EGemoI2N...
# 73988  https://play-lh.googleusercontent.com/EGemoI2N...
# 73989  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      Setiap apply lamaran disini, bbrpa hari atau b...      1
# 1      min tolong ini ngebug, masa pas mau buka lowon...      3
# 2                                               Worth it      2
# 3               Jadi susah re login by seek, gagal terus      1
# 4      TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...      1
# ...                                                  ...    ...
# 73985                           Good luck for us all....      4
# 73986                                                Top      5
# 73987                                                 Ok      4
# 73988                               thanks for the job..      5
# 73989  Nice app, runing on my gio. But somehow thing ...      3
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                  0              14.33.0  2024-12-12 08:14:23
# 1                  0              14.33.0  2024-12-12 07:29:09
# 2                  0              14.33.0  2024-12-12 04:27:59
# 3                  0              14.32.0  2024-12-11 23:41:41
# 4                  0              14.32.0  2024-12-11 22:51:25
# ...              ...                  ...                  ...
# 73985              0                  NaN  2012-08-31 00:34:55
# 73986              0                  NaN  2012-07-30 14:56:50
# 73987              0                1.2.1  2012-04-06 09:09:14
# 73988              0                  1.1  2011-10-04 17:06:05
# 73989              1                  1.0  2011-06-10 22:53:23
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4      Hi, kami meminta maaf atas ketidaknyamanan yan...  2024-12-04 08:43:34
# ...                                                  ...                  ...
# 73985                                                NaN                  NaN
# 73986                                                NaN                  NaN
# 73987                                                NaN                  NaN
# 73988                                                NaN                  NaN
# 73989                                                NaN                  NaN
#
#       appVersion
# 0        14.33.0
# 1        14.33.0
# 2        14.33.0
# 3        14.32.0
# 4        14.32.0
# ...          ...
# 73985        NaN
# 73986        NaN
# 73987      1.2.1
# 73988        1.1
# 73989        1.0
#
# [73990 rows x 11 columns]
